# %%
'''
Assignment Questions:
1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
    Qualitative data represents characteristics or labels that describe an attribute rather than measuring it numerically. This type of data is used for classification.
    Examples:
          Eye color (brown, blue, green)
          Types of cuisine (Italian, Mexican, Chinese)
          Customer feedback (satisfied, neutral, dissatisfied)
    Subtypes of Qualitative Data:
      Nominal Data
        Consists of names, labels, or categories that have no specific order.
        Example: Gender (Male, Female), Hair Color (Black, Brown, Blonde)
        Key Feature: No ranking or hierarchy.
     Ordinal Data
        Includes categories that have a meaningful order but the difference between them is not uniform.
        Example: Education Levels (High School, Bachelor’s, Master’s), Satisfaction Ratings (Poor, Fair, Good, Excellent)
        Key Feature: Ranked data but no precise measurement between ranks.

   Quantitative data consists of numerical values that can be measured or counted. It allows for mathematical computations and statistical analysis.
   Examples:
        Height of students (160 cm, 170 cm)
        Temperature readings (32°C, 50°F)
        Number of customers in a store (10, 25, 100)
    Subtypes of Quantitative Data:
     Interval Data
       Numeric data with equal intervals between values but no true zero point.
       Example: Temperature in Celsius or Fahrenheit (0°C does not mean "no temperature"), Years (2000, 2020)
       Key Feature: Equal differences between values, but zero is arbitrary.
     Ratio Data
        Numeric data with equal intervals and a true zero, allowing for meaningful ratios.
        Example: Weight (0 kg means no weight), Income ($0 means no income), Distance (0 km means no distance traveled)
        Key Feature: True zero allows for meaningful comparisons (e.g., 10 kg is twice as heavy as 5 kg).

2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
    Measures of central tendency help summarize a set of data by identifying a central value. The three main types are mean, median, and mode.
      Mean: Sum of all values divided by count. Best use case in case of symmetrical data, no outliers, numerical analysis. Avoid in case of Skewed data, outliers.
      Median: Middle value when sorted. Best use case in case of skewed data, outliers, ordinal data. Avoid in case of symmetrical data without outliers
      Mode: Most frequently occurring value. Best use case in case of categorical data, identifying common trends. Avoid in case of when all values are equally frequent.


3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
    Dispersion refers to the spread or variability of a dataset. It helps understand how much data points deviate from the central value (such as the mean).
    A high dispersion means the data points are spread out, while low dispersion means they are close to the central value.
      Variance : Variance measures the average squared deviation of each data point from the mean. It tells us how much the data varies but in squared units.
      Standard deviation : The standard deviation is the square root of the variance. It brings variance back to the same units as the original data, making it easier to interpret.

4. What is a box plot, and what can it tell you about the distribution of data?
    A box plot (box-and-whisker plot) is a graphical representation of a dataset’s spread and distribution.
    It shows key statistical values, including the median, quartiles, and outliers, providing a quick visual summary of data distribution.

5. Discuss the role of random sampling in making inferences about populations.
    Random sampling is a fundamental technique in statistics that allows researchers to make reliable inferences about a population based on a sample. Instead of studying an entire population, which is often impractical or impossible, random sampling helps ensure that the sample accurately represents the population, minimizing bias and allowing for generalization.

6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
    Skewness is a measure of the asymmetry in a dataset’s distribution. It indicates whether the data is symmetrically distributed or if it leans more toward one side.
     Symmetric Data → No skewness (bell-shaped curve).
     Skewed Data → More values are concentrated on one side, creating a tail.
     Understanding skewness helps in choosing the right statistical tools, avoiding misleading interpretations, and making informed decisions based on data distribution.
     The median is more reliable when data is skewed because it is not affected by outliers.

7. What is the interquartile range (IQR), and how is it used to detect outliers?
   The Interquartile Range (IQR) is a measure of statistical dispersion, showing the range within which the middle 50% of the data falls. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1).
   Steps to detect outliers using IQR:
        1.Compute the IQR
        2.Define the Outlier Boundaries.( Lower ->  Q1−1.5×IQR . Upper -> Q3+1.5×IQR )
        3.Any value outside these bounds is considered an outlier.

8. Discuss the conditions under which the binomial distribution is used.
   The binomial distribution is used to model situations where an experiment is repeated a fixed number of times, and each trial results in one of two possible outcomes.
   These conditions must be met for the binomial distribution to be appropriate:
     1. Fixed Number of Trials (n)
     2. Two Possible Outcomes (Success or Failure)
     3. Constant Probability of Success (p)
     4. Independence of Trials (Trials are not influenced by each other)

9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
   The normal distribution, also known as the Gaussian distribution, is one of the most important probability distributions in statistics.
    1. The normal distribution is perfectly symmetric around the mean.
    2. The graph of the normal distribution is bell-shaped, with the highest point at the mean.
    3. The standard deviation determines the width of the distribution.
    4. Mean, Median, Mode are Equal.
    5. The tails of the normal distribution curve never touch the horizontal axis. They get closer to zero but never reach it.
    6. The empirical rule states that 68% of the data falls within one standard deviation of the mean, 95% within two standard deviations, and 99.7% within three standard deviations.

10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
    A Poisson process is a statistical model used to describe random events that occur independently over a fixed interval of time or space, at a constant average rate.
    The events must occur randomly and without any predictable pattern. The Poisson process is typically used in scenarios where:
      1.Events happen rarely but are independent of each other.
      2.The events happen at a constant average rate.

      A real-life example of a Poisson process is the number of phone calls received by a customer service center per hour, assuming the calls come in independently at a constant average rate throughout the hour; let's say the average call rate is 5 calls per hour.
      To calculate the probability of receiving exactly 2 calls in a given hour, we can use the Poisson distribution formula: P(X=2) = (e^(-5) * 5^2) / 2! which is approximately 0.084, meaning there's an 8.4% chance of receiving exactly 2 calls in that hour.

11. Explain what a random variable is and differentiate between discrete and continuous random variables.
    Discrete variables have distinct, separate values with gaps between them, while continuous variables have an unbroken sequence of values.

12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
     Let's consider a simple dataset with the scores of two students on two different subjects:
     Student   Maths Score   Science Score
      A         85              90
      B         78              82
      C         92              88
      D         88              85
      E         95              83

    We'll calculate both the covariance and correlation between the Math Scores (X) and Science Scores (Y).
       Mean of X : 87.6
       Mean of Y : 85.6

           Cov(X, Y) = Σ(Xi-µx)(Y-µy) / n
           Σ(Xi-µx)(Y-µy) = −11.44+34.56+10.56−0.24−19.24=14.2
           Cov(X, Y) = 14.2/5 = 2,84

   Correlation = Cov (X,Y)/σXσY
​   where σX and σY are the standard deviations of X and Y.

    σX =  5.89
    σY =  3.01

    Correlation (r) = 2.84/(5.89 * 3.01)
                    = 0.16

​Covariance (2.84) : Shows that as Maths scores increase, Science scores tend to increase as well.
Correlation (0.16): Indicates that the relationship between Maths and Science scores is weak. The scores do not have a strong linear dependenc

'''
# Out:
# '\nAssignment Questions:\n1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.\n    Qualitative data represents characteristics or labels that describe an attribute rather than measuring it numerically. This type of data is used for classification.\n    Examples:\n          Eye color (brown, blue, green)\n          Types of cuisine (Italian, Mexican, Chinese)\n          Customer feedback (satisfied, neutral, dissatisfied)\n    Subtypes of Qualitative Data:\n      Nominal Data\n        Consists of names, labels, or categories that have no specific order.\n        Example: Gender (Male, Female), Hair Color (Black, Brown, Blonde)\n        Key Feature: No ranking or hierarchy.\n     Ordinal Data\n        Includes categories that have a meaningful order but the difference between them is not uniform.\n        Example: Education Levels (High School, Bachelor’s, Master’s), Satisfaction Ratin
# ...
